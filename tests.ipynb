# %%
import pandas
from docx import Document
import pymupdf
from pathlib import Path

# %%
p = Path('data')

# %%
with pymupdf.open(p/'test_text.pdf') as pdf:
    text = chr(12).join([page.get_text() for page in pdf])
print(text)

# %%
import cv2
import Image
import pytesseract

# %%
path = (p/'test.png').resolve()
img_cv = cv2.imread(rf'{path}')
# print(img_cv)
img_cv = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
# img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
print(pytesseract.image_to_string(img_rgb, lang='rus'))

# %%
path.resolve()
# Out:
# PosixPath('/home/oliver/laborant_app/data/test.png')

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

model = ocr_predictor(pretrained=True)
doc = DocumentFile.from_images(path.resolve())
result = model(doc)
print(result)
# Out:
# Document(
#   (pages): [Page(
#     dimensions=(1080, 766)
#     (blocks): [
#       Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='NABOPATOPMS', confidence=0.4),
#               Word(value='Hay-Hbih', confidence=0.4),
#               Word(value='yeHrp', confidence=0.39),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='AHKOM', confidence=1.0),
#               Word(value='wcChenoBaHA', confidence=0.27),
#             ]
#           ),
#         ]
#         (artefacts): []
#       ),
#       Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='+7', confidence=0.86),
#               Word(value='495', confidence=1.0),
#               Word(value='540-42-75', confidence=0.93),
#               Word(value='dnkom.ru', confidence=0.6),
#               Word(value='info@dnkom.ru', confidence=0.78),
#             ]
#           ),
#           Line(
# ...
